# %% [markdown]
# <h1><b>HW1: Thu thập và tiền xử lý dữ liệu</b></h1>
#
# Họ tên: HUỲNH VĂN THÁI
#
# MSSV: 21424088
#
# <hr />
#
# <h2><b>Cách làm và nộp bài</b></h2>
# <b>Cách làm bài</b>
#
# Các bạn sẽ làm trực tiếp trên file notebook này. Đầu tiên, bạn điền họ tên và MSSV của mình ở bên trên. Trong file, bạn sẽ làm ở những phần có ghi là:
#
# <i style="background-color:tomato"><FONT COLOR="green"># YOUR CODE HERE</FONT></i>
#
# <FONT COLOR="green">raise</FONT> NotImplementedError()
#
# Tất nhiên, khi làm bạn sẽ xóa dòng <b>raise NotImplementedError()</b> đi. Đối với những phần yêu cầu làm thì thường ở ngay phía dưới sẽ có một (hoặc một số) cell chứa các bộ test để giúp bạn biết đã code đúng hay chưa. Nếu chạy cell này không có lỗi gì thì có nghĩa là qua được các bộ test và ngược lại, nếu không qua được test thì là code sai, nhưng nếu qua được test thì chưa chắc đã đúng.
# </br></br>
# Trong khi làm bài, bạn có thể cho in ra màn hình, tạo thêm các cell để test. Tuy nhiên, khi nộp bài thì code của các bạn sẽ được chạy lại, do đó phải xóa các cell mà bạn đã tạo ra trước đó đi. Ngoài ra, bạn lưu ý là tuyệt đối không được tự tiện xóa các cell hay sửa code của Thầy (trừ những chỗ được phép sửa như đã đề cập ở trên).
# </br></br>
# Trong khi làm bài, thương xuyên lưu lại bài của bạn để tránh mất mát thông tin. Ngoài ra, chúng ta cần hết sức lưu ý là việc đạo văn là bị nghiêm cấm và sẽ bị xử lý đối với các bài làm giống nhau. Mục tiêu chính của chúng ta là học một cách chân thật, các bạn có thể tham khảo ý tưởng từ bạn bè của bạn hay từ các nguồn tham khảo khác trên mạng. Tuy nhiên, phần bài làm cuối cùng vẫn phải là của bạn dựa trên những sự hiểu biết thực sự. Khi tham khảo các nguồn trên mạng thì bạn cũng nên ghi rõ nguồn đó trong bài làm của mình. <font color='red'>Trong trường hợp các bạn vi phạm những điều mình đã đề cập ở trên thì sẽ bị 0 điểm cho toàn bộ môn học này.</font>
#
# <h5><b>Cách nộp bài</h5></b>
#
# Khi chấm bài, mình sẽ chọn Kernel - Restart & Run All để chạy lại toàn bộ code của các bạn từ ban đầu trên google colab. Do đó, để đảm bảo code các bạn không bị lỗi, các bạn nên chạy thử như mình chạy để đảm bảo mọi thứ diễn ra như mong đợi.
#
# Sau đó, bạn tạo thư mục nộp bài theo các yêu cầu sau:
# * Đầu tiên, các bạn tạo một thư mục MSSV (vd, nếu bạn có MSSV là 123456 thì bạn đặt tên thư mục là 123456)
# * Trong thư mục, MSSV vừa tạo, bạn bỏ file notebook bài làm của bạn vào cùng với file project được tạo bởi thư viện scrapy (file project khi tạo này các bạn có thể đặt bất kỳ tên gì)
# * Cuối cùng, bạn nén thư mục MSSV này lại và nộp ở link trên moodle. Đuôi của file nén phải là .zip (chứ không được .rar hay gì khác).
#
# <font color='red'>Bạn lưu ý tuân thủ chính xác qui định nộp bài ở trên, nếu nộp sai quy định sẽ bị trừ nửa số điểm cho bài làm của mình.</font>
# </br></br>
# <hr />
# </br>
# <h2><b>Import</b></h2>
#
# Trong bài thực hành này vì dữ liệu thu thập của chúng ta sẽ rất lớn, nên mình sẽ giúp các bạn thu thập dữ liệu được nhanh chóng bằng cách sử dụng một thư viện có tên scrapy. Vì thư viện này không có sẵn nên các bạn cần cài đặt trước khi sử dụng.

# %%
# !pip install scrapy
# !pip install spider3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scrapy
#   Downloading Scrapy-2.8.0-py2.py3-none-any.whl (272 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.9/272.9 KB 6.9 MB/s eta 0:00:00
# Collecting tldextract
#   Downloading tldextract-3.4.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 KB 6.8 MB/s eta 0:00:00
# Collecting parsel>=1.5.0
#   Downloading parsel-1.7.0-py2.py3-none-any.whl (14 kB)
# Collecting PyDispatcher>=2.0.5
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Collecting cssselect>=0.9.1
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting itemloaders>=1.0.1
#   Downloading itemloaders-1.0.6-py3-none-any.whl (11 kB)
# Collecting protego>=0.1.15
#   Downloading Protego-0.2.1-py2.py3-none-any.whl (8.2 kB)
# Collecting cryptography>=3.4.6
#   Downloading cryptography-39.0.2-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 56.9 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from scrapy) (63.4.3)
# Collecting itemadapter>=0.1.0
#   Downloading itemadapter-0.7.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from scrapy) (23.0)
# Collecting Twisted>=18.9.0
#   Downloading Twisted-22.10.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 38.4 MB/s eta 0:00:00
# Collecting w3lib>=1.17.0
#   Downloading w3lib-2.1.1-py3-none-any.whl (21 kB)
# Collecting pyOpenSSL>=21.0.0
#   Downloading pyOpenSSL-23.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 KB 3.0 MB/s eta 0:00:00
# Collecting service-identity>=18.1.0
#   Downloading service_identity-21.1.0-py2.py3-none-any.whl (12 kB)
# Collecting zope.interface>=5.1.0
#   Downloading zope.interface-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 KB 7.7 MB/s eta 0:00:00
# Collecting queuelib>=1.4.2
#   Downloading queuelib-1.6.2-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: lxml>=4.3.0 in /usr/local/lib/python3.9/dist-packages (from scrapy) (4.9.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=3.4.6->scrapy) (1.15.1)
# Collecting jmespath>=0.9.5
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from protego>=0.1.15->scrapy) (1.15.0)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.9/dist-packages (from service-identity>=18.1.0->scrapy) (0.2.8)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.9/dist-packages (from service-identity>=18.1.0->scrapy) (22.2.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.9/dist-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Collecting hyperlink>=17.1.1
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 KB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.9/dist-packages (from Twisted>=18.9.0->scrapy) (4.5.0)
# Collecting incremental>=21.3.0
#   Downloading incremental-22.10.0-py2.py3-none-any.whl (16 kB)
# Collecting Automat>=0.8.0
#   Downloading Automat-22.10.0-py2.py3-none-any.whl (26 kB)
# Collecting constantly>=15.1
#   Downloading constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.9/dist-packages (from tldextract->scrapy) (3.4)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from tldextract->scrapy) (2.27.1)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.9/dist-packages (from tldextract->scrapy) (3.10.0)
# Collecting requests-file>=1.4
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=3.4.6->scrapy) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.12)
# Installing collected packages: PyDispatcher, incremental, constantly, zope.interface, w3lib, queuelib, protego, jmespath, itemadapter, hyperlink, cssselect, Automat, Twisted, requests-file, parsel, cryptography, tldextract, service-identity, pyOpenSSL, itemloaders, scrapy
# Successfully installed Automat-22.10.0 PyDispatcher-2.0.7 Twisted-22.10.0 constantly-15.1.0 cryptography-39.0.2 cssselect-1.2.0 hyperlink-21.0.0 incremental-22.10.0 itemadapter-0.7.0 itemloaders-1.0.6 jmespath-1.0.1 parsel-1.7.0 protego-0.2.1 pyOpenSSL-23.0.0 queuelib-1.6.2 requests-file-1.5.1 scrapy-2.8.0 service-identity-21.1.0 tldextract-3.4.0 w3lib-2.1.1 zope.interface-6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spider3
#   Downloading spider3-1.0.2-py3-none-any.whl (3.9 kB)
# Installing collected packages: spider3
# Successfully installed spider3-1.0.2

# %%
import json
import re
import pandas as pd
import scrapy
from pandas.testing import assert_frame_equal # to compare two dataframes
# YOUR CODE HERE (OPTION) 
# Nếu cần các thư viện khác thì bạn có thể import thêm tại đây
import datetime

# %% [markdown]
# Như bạn đã biết, bóng đá là môn thể thao hấp dẫn nhất hành tinh. Chúng ta sẽ khởi động môn học bằng việc thu thập dữ liệu của các cầu thủ bóng đá. <b>SoFIFA</b> (https://sofifa.com/) là một trang web lưu trữ dữ liệu của các cầu thủ trong trò chơi bóng đá nổi tiếng FIFA 23 mà có các chỉ số phản ánh gần đúng với phong độ của các cầu thủ bóng đá ngoài đời. Trong phần này, nhiệm vụ đầu tiên của bạn là sẽ cần thu thập ID của các cầu thủ. Mình có check "Terms of Service" của SoFIFA thì không thấy có mục nào nói là cấm parse HTML, vì vậy với mục đích học thì chắc là không có vấn đề gì lớn, miễn là chương trình của bạn đừng "hit" trang web quá nhiều lần trong một khoảng thời gian ngắn thì sẽ không có vấn đề gì.
# </br></br>
# Công việc cụ thể của bạn ở phần đầu tiên này là sẽ cần viết class <b>collect_player_url()</b> ở bên dưới. Vì dữ liệu lúc sau các bạn cần thu thập sẽ rất lớn nên ở đây, chúng ta sẽ xài một thư viên có tên scrapy để có thể thu thập dữ liệu lớn được nhanh chóng hơn. Về cách sử dụng thư viện này thì bạn có thể tham khảo thêm tại trang web sau: https://docs.scrapy.org/en/latest/intro/tutorial.html.
# </br></br>
# <h2><b>Tạo một project mới với scrapy</b><h2>
#
# Để sử dụng thư viện scrapy sau khi cài đặt xong, các bạn sẽ gọi câu lệnh như bên dưới để bắt đầu tạo một project mới với scrapy với tên gọi là <b>"fifa_crawler"</b>.

# %%
# !scrapy startproject fifa_crawler

# %%
cd fifa_crawler/fifa_crawler

# %% [markdown]
# Sau khi tạo xong project với scrapy, vì thu thập dữ liệu với thư viện này không cho phép xài notebook trực tiếp nên các bạn sau khi hoàn thành xong class <b>collect_player_url(scrapy.Spider)</b> ở bên dưới, các bạn cần tạo một file có tên <b>collect_players_urls.py</b> vào đường dẫn sau <b>fifa_crawler/fifa_crawler/spiders/collect_players_urls.py</b>. Ngoài ra, để tránh việc <b>hit</b> trang web quá nhiều lần, thay vì thu thập toàn bộ ID các cầu thủ của thì các bạn sẽ chỉ cần thu thập 720 ID cầu thủ. Để cho dễ dàng, mình đã để sẵn 1 đường dẫn urls chứa định dạng offset (từng trang của các cầu thủ với mỗi trang chứa 60 cầu thủ khác nhau) để các bạn có thể dễ dàng chuyển trang mới trong lúc thu thập.

# %%
import scrapy

class collect_player_url(scrapy.Spider):
  name='players_urls' 
  
  def start_requests(self):
    urls = ['https://sofifa.com/players?col=oa&sort=desc&offset=0']
    
    # YOUR CODE HERE
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

    for i in range(1,13):
        url = f'https://sofifa.com/players?col=oa&sort=desc&offset={i}' 
        urls.append(url)

    for url in urls:
      yield scrapy.Request(url=url, headers=headers, callback=self.parse)

  def parse(self, response):
    player_urls = response.css('td.col-name a[role="tooltip"]::attr(href)').extract()
    player_ids = []
    for url in player_urls:
      if url.split('/')[1] == "player":
        player_id = url.split('/')[2]
        player_url = f"/player/{player_id}"
        player_item = {"player_url": player_url}
        yield player_item

# %% [markdown]
# Sau khi đã viết xong class trên, và đã tạo file <b>collect_players_urls.py</b> trong đường dẫn đã đề cập, bạn sẽ tiến hành gọi lệnh như bên dưới để thu thập ID của các cầu thủ bóng đá và lưu vào một file có tên <b>players_urls.json</b> mà chứa trong thư mục dataset. Thư mục dataset này bạn không cần tạo mà khi thu thập dữ liệu scrapy sẽ tự động tạo cho bạn.

# %%
# !scrapy crawl players_urls -o dataset/players_urls.json

# %% [markdown]
# Sau khi đã có danh sách 720 ID của các cầu thủ đã thu thập từ trang web SoFIFA, bạn sẽ tiến hành thu thập dữ liệu cụ thể của từng cầu thủ ứng với các ID này bằng cách hoàn thành class <b>collect_player_info(scrapy.Spider)</b> như bên dưới. Các bạn cũng lưu ý lại là như mình đã đề cập, việc sử dụng scrapy trực tiếp notebook là không được mà chúng ta sẽ cần tạo tiếp một file mới có tên <b>collect_players_info.py</b> vào cùng đường dẫn như file <b>collect_players_urls.py</b>. Ở đây, cũng để cho tiện thì mình cũng để cho các bạn 1 đường dẫn url mới với ID 231747 ứng với ID đầu tiên mà chúng ta đã thu thập ở bước trước. Nhiệm vụ của các bạn là dựa vào url này để tiếp tục hoàn thành việc parse HTML và thu thập các thông tin chi tiết của ID này (chúng ta cũng làm tương tự cho 719 ID còn lại). Về chi tiết tất cả các dữ liệu các bạn cần thu thập thì mình có để sẵn 1 file test có tên <b>players_info.json</b> là file đã được mình thu thập về thông tin chi tiết của 720 cầu thủ cho các bạn.

# %%
df_test = pd.read_json('/content/players_info.json', encoding='utf-8-sig')
df_test.iloc[0]

# %%
import scrapy
import json
import re
import datetime

class collect_player_info(scrapy.Spider):
  name='players_info'
  
  def __init__(self):
    try:
      with open('dataset/players_urls.json') as f:
        self.players = json.load(f)
      self.player_count = 1
    except IOError:
      print("File not found")

  def start_requests(self):
    urls = ['https://sofifa.com/player/231747?units=mks']
    # YOUR CODE HERE
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    
    for player in self.players:
      url = 'https://sofifa.com' + player['player_url'] + '?units=mks'
      yield scrapy.Request(url=url, headers=headers, callback=self.parse)
  
  def parse(self, response):
      # YOUR CODE HERE
      id = response.css('li:contains("ID")::text').get().strip()
      name = response.css('div.info h1::text').get()
      primary_position = response.css('ul.pl li:nth-child(1) span.pos::text').get()
      positions = []
      for pos in response.css('ul.ellipsis.pl li span.pos::text').getall():
        positions.append(pos)
      # extract age, date of birth, height, and weight
      meta_info = response.css('div.info div.meta.ellipsis::text').getall()
      # Assuming that meta_info is already defined
      age = re.search(r'(\d{2})y\.o\.', meta_info[1]).group(1)
      birth_date = datetime.datetime.strptime(re.search(r'\((.*?)\)', meta_info[1]).group(1), '%b %d, %Y').strftime('%Y/%b/%d')
      height = int(re.search(r'(\d{3})cm', meta_info[1]).group(1))
      weight = int(re.search(r'(\d{2,3})lbs', meta_info[1]).group(1))
      overall_rating = int(response.css('section.card.spacing div.block-quarter:nth-child(1) span.p::text').get())
      potential = response.css('section.card.spacing div.block-quarter:nth-child(2) span.p::text').get()
      value = response.css('div.block-quarter:nth-child(3) div::text').get().strip()
      wage = response.css('div.block-quarter:nth-child(4) div::text').get().strip()
      preferred_foot = response.css('li.ellipsis:contains("Preferred Foot")::text').get().strip().replace("Preferred Foot", "")
      weak_foot = int(response.css('li.ellipsis:contains("Weak Foot")::text').get().strip()[0])
      skill_moves = int(response.css('li.ellipsis:contains("Skill Moves")::text').get().strip()[0])
      international_reputation = int(response.css('li.ellipsis:contains("International Reputation")::text').get().strip()[0])
      work_rate = response.css('li:contains("Work Rate") span::text').get()
      body_type = response.css('ul.pl li:contains("Body Type") span::text').get()
      real_face = response.css('ul.pl li:contains("Real Face") span::text').get()
      release_clause = response.css('ul.pl li:contains("Release Clause") span::text').get()
      teams = dict(zip(response.css('div.card h5 a::text').getall(), response.css('ul.ellipsis.pl li span.bp3-tag.p::text').getall()))
      stats_names =  response.css('div.grid div.block-quarter div.card h5::text').getall()
      stats_values = response.css('div.card ul.pl li span.bp3-tag::text').getall()
      stats_keys = response.css('div.card ul.pl li span[role="tooltip"]::text').getall()
      attacking = dict(zip(stats_keys[0:4],list(map(int, stats_values[0:4]))))
      skill = dict(zip(stats_keys[5:9],list(map(int, stats_values[5:9]))))
      movement = dict(zip(stats_keys[10:14],list(map(int, stats_values[10:14]))))
      power = dict(zip(stats_keys[15:19],list(map(int, stats_values[15:19]))))
      mentality = dict(zip(stats_keys[20:25],list(map(int, stats_values[20:25]))))
      defending = dict(zip(stats_keys[26:28],list(map(int, stats_values[26:28]))))
      goalkeeping = dict(zip(stats_keys[29:33],list(map(int, stats_values[29:33]))))
      player_traits = stats_keys[34:38]
      player_specialities = response.css('div.card ul.pl li a::text').getall()
        
      player_info = {
        "id": id,
        "name": name.encode('unicode_escape').decode(),
        "primary_position": primary_position,
        "positions": positions,
        "age": age,
        "birth_date":birth_date,
        "height": height, 
        "weight": weight,
        "Overall Rating": overall_rating,
        "Potential": potential,
        "Value": value.encode('unicode_escape').decode(), 
        "Wage": wage.encode('unicode_escape').decode(),
        "Preferred Foot": preferred_foot,
        "Weak Foot": weak_foot,
        "Skill Moves":skill_moves,
        "International Reputation": international_reputation,
        "Work Rate": work_rate,
        "Body Type": body_type,
        "Real Face": real_face,
        "Release Clause": release_clause.encode('unicode_escape').decode(),
        "teams": teams,
        "attacking": attacking,
        "skill": skill,
        "power": power,
        "mentality": mentality,
        "defending": defending,
        "goalkeeping": goalkeeping,
        "player_traits": player_traits,
        "player_specialities": player_specialities
        }
      yield player_info

# %% [markdown]
# Sau khi đã hoàn thành class ở trên và lưu lại trong file <b>collect_players_info.py</b>, các bạn sẽ tiếp tục chạy câu lệnh bên dưới để thu thập thông tin chi tiết của toàn bộ 720 cầu thủ và xuất ra file <b>players_info.json</b> ở cùng đường dẫn dataset như trên.

# %%
# !scrapy crawl players_info -o dataset/players_info.json
# Out:
# 2023-03-19 16:15:15 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: fifa_crawler)
# 2023-03-19 16:15:15 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.9.16 (main, Dec  7 2022, 01:11:51) - [GCC 9.4.0], pyOpenSSL 23.0.0 (OpenSSL 3.0.8 7 Feb 2023), cryptography 39.0.2, Platform Linux-5.10.147+-x86_64-with-glibc2.31
# 2023-03-19 16:15:15 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'fifa_crawler',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'fifa_crawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['fifa_crawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-03-19 16:15:15 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-03-19 16:15:15 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-03-19 16:15:15 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2023-03-19 16:15:15 [scrapy.extensions.telnet] INFO: Telnet Password: c5bc9dcde4ac706a
# 2023-03-19 16:15:15 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-03-19 16:15:15 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-03-19 16:15:15 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-03-19 16:15:15 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-03-19 16:15:15 [scrapy.core.engine] INFO: Spider opened
# 2023-03-19 16:15:15 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-03-19 16:15:15 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-03-19 16:15:15 [scrapy.core.engine] DEBUG: Crawled (403) <GET https://sofifa.com/robots.txt> (referer: None)
# 2023-03-19 16:15:15 [protego] DEBUG: Rule at line 10 without any user agent to enforce it on.
# 2023-03-19 16:15:15 [protego] DEBUG: Rule at line 14 without any user agent to enforce it on.
# 2023-03-19 16:15:15 [protego] DEBUG: Rule at line 16 without any user agent to enforce it on.
# 2023-03-19 16:15:15 [protego] DEBUG: Rule at line 35 without any user agent to enforce it on.
# 2023-03-19 16:15:15 [protego] DEBUG: Rule at line 42 without any user agent to enforce it on.
# 2023-03-19 16:15:15 [protego] DEBUG: Rule at line 43 without any user agent to enforce it on.
# 2023-03-19 16:15:15 [protego] DEBUG: Rule at line 44 without any user agent to enforce it on.
# 2023-03-19 16:15:15 [protego] DEBUG: Rule at line 45 without any user agent to enforce it on.
# 2023-03-19 16:15:15 [protego] DEBUG: Rule at line 46 without any user agent to enforce it on.
# 2023-03-19 16:15:15 [protego] DEBUG: Rule at line 47 without any user agent to enforce it on.
# 2023-03-19 16:15:15 [protego] DEBUG: Rule at line 69 without any user agent to enforce it on.
# 2023-03-19 16:15:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/212831?units=mks> (referer: None)
# 2023-03-19 16:15:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/209331?units=mks> (referer: None)
# 2023-03-19 16:15:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/165153?units=mks> (referer: None)
# 2023-03-19 16:15:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/158023?units=mks> (referer: None)
# 2023-03-19 16:15:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/192119?units=mks> (referer: None)
# 2023-03-19 16:15:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/239085?units=mks> (referer: None)
# 2023-03-19 16:15:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/188545?units=mks> (referer: None)
# 2023-03-19 16:15:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/212622?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/212831?units=mks>
# {'id': '212831', 'name': 'Alisson Rams\\xe9s Becker', 'primary_position': 'GK', 'positions': ['GK'], 'age': '29', 'birth_date': '1992/Oct/02', 'height': 193, 'weight': 201, 'Overall Rating': 89, 'Potential': '90', 'Value': '\\u20ac79M', 'Wage': '\\u20ac190K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 1, 'International Reputation': 3, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac152.1M', 'teams': {' Liverpool': '84'}, 'attacking': {'Crossing': 84, 'Finishing': 17, 'Heading Accuracy': 13, 'Short Passing': 29}, 'skill': {'Dribbling': 20, 'Curve': 27, 'FK Accuracy': 19, 'Long Passing': 18}, 'power': {'Shot Power': 37, 'Jumping': 64, 'Stamina': 52, 'Strength': 32}, 'mentality': {'Aggression': 14, 'Interceptions': 27, 'Positioning': 11, 'Vision': 13, 'Penalties': 66}, 'defending': {'Defensive Awareness': 66, 'Standing Tackle': 15}, 'goalkeeping': {'GK Diving': 16, 'GK Handling': 86, 'GK Kicking': 85, 'GK Positioning': 85}, 'player_traits': ['GK Long Throw', 'Rushes Out Of Goal', 'Comes For Crosses'], 'player_specialities': []}
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/209331?units=mks>
# {'id': '209331', 'name': 'Mohamed Salah Ghaly', 'primary_position': 'RW', 'positions': ['RW'], 'age': '30', 'birth_date': '1992/Jun/15', 'height': 175, 'weight': 157, 'Overall Rating': 89, 'Potential': '89', 'Value': '\\u20ac99.5M', 'Wage': '\\u20ac260K', 'Preferred Foot': 'Left', 'Weak Foot': 3, 'Skill Moves': 4, 'International Reputation': 4, 'Work Rate': 'High/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac184.1M', 'teams': {' Liverpool': '84'}, 'attacking': {'Crossing': 84, 'Finishing': 80, 'Heading Accuracy': 92, 'Short Passing': 59}, 'skill': {'Dribbling': 83, 'Curve': 88, 'FK Accuracy': 84, 'Long Passing': 69}, 'power': {'Shot Power': 91, 'Jumping': 82, 'Stamina': 69, 'Strength': 87}, 'mentality': {'Aggression': 84, 'Interceptions': 63, 'Positioning': 55, 'Vision': 91, 'Penalties': 84}, 'defending': {'Defensive Awareness': 90, 'Standing Tackle': 38}, 'goalkeeping': {'GK Diving': 41, 'GK Handling': 14, 'GK Kicking': 14, 'GK Positioning': 9}, 'player_traits': ['Finesse Shot', 'Long Shot Taker (AI)', 'Speed Dribbler (AI)', 'Outside Foot Shot'], 'player_specialities': ['#Dribbler', '#Acrobat', '#Clinical Finisher', '#Complete Forward']}
# 2023-03-19 16:15:16 [scrapy.core.scraper] ERROR: Spider error processing <GET https://sofifa.com/player/165153?units=mks> (referer: None)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/content/fifa_crawler/fifa_crawler/spiders/collect_players_info.py", line 38, in parse
#     age = re.search(r'(\d{2})y\.o\.', meta_info[1]).group(1)
# AttributeError: 'NoneType' object has no attribute 'group'
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/202126?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/203376?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/158023?units=mks>
# {'id': '158023', 'name': 'Lionel Andr\\xe9s Messi Cuccittini', 'primary_position': 'CAM', 'positions': ['RS', 'RW'], 'age': '35', 'birth_date': '1987/Jun/24', 'height': 169, 'weight': 148, 'Overall Rating': 91, 'Potential': '91', 'Value': '\\u20ac54M', 'Wage': '\\u20ac195K', 'Preferred Foot': 'Left', 'Weak Foot': 4, 'Skill Moves': 4, 'International Reputation': 5, 'Work Rate': 'Low/ Low', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac99.9M', 'teams': {' Paris Saint Germain': '84', ' Argentina': '83'}, 'attacking': {'Crossing': 84, 'Finishing': 83, 'Heading Accuracy': 84, 'Short Passing': 90}, 'skill': {'Dribbling': 91, 'Curve': 88, 'FK Accuracy': 95, 'Long Passing': 93}, 'power': {'Shot Power': 92, 'Jumping': 95, 'Stamina': 86, 'Strength': 68}, 'mentality': {'Aggression': 68, 'Interceptions': 91, 'Positioning': 44, 'Vision': 40, 'Penalties': 93}, 'defending': {'Defensive Awareness': 75, 'Standing Tackle': 96}, 'goalkeeping': {'GK Diving': 35, 'GK Handling': 24, 'GK Kicking': 6, 'GK Positioning': 11}, 'player_traits': ['Finesse Shot', 'Long Shot Taker (AI)', 'Playmaker (AI)', 'Outside Foot Shot'], 'player_specialities': ['#Dribbler', '#Distance Shooter', '#FK Specialist', '#Acrobat', '#Clinical Finisher', '#Complete Forward']}
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/192119?units=mks>
# {'id': '192119', 'name': 'Thibaut Nicolas Marc Courtois', 'primary_position': 'GK', 'positions': ['GK', 'GK'], 'age': '30', 'birth_date': '1992/May/11', 'height': 199, 'weight': 212, 'Overall Rating': 90, 'Potential': '91', 'Value': '\\u20ac90M', 'Wage': '\\u20ac250K', 'Preferred Foot': 'Left', 'Weak Foot': 3, 'Skill Moves': 1, 'International Reputation': 4, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac191.3M', 'teams': {' Real Madrid': '85', ' Belgium': '82'}, 'attacking': {'Crossing': 85, 'Finishing': 82, 'Heading Accuracy': 14, 'Short Passing': 14}, 'skill': {'Dribbling': 33, 'Curve': 12, 'FK Accuracy': 13, 'Long Passing': 19}, 'power': {'Shot Power': 84, 'Jumping': 45, 'Stamina': 56, 'Strength': 68}, 'mentality': {'Aggression': 70, 'Interceptions': 17, 'Positioning': 23, 'Vision': 15, 'Penalties': 13}, 'defending': {'Defensive Awareness': 27, 'Standing Tackle': 66}, 'goalkeeping': {'GK Diving': 18, 'GK Handling': 16, 'GK Kicking': 84, 'GK Positioning': 89}, 'player_traits': ['GK Long Throw', 'Comes For Crosses'], 'player_specialities': []}
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/239085?units=mks>
# {'id': '239085', 'name': 'Erling Braut Haaland', 'primary_position': 'ST', 'positions': ['ST', 'ST'], 'age': '21', 'birth_date': '2000/Jul/21', 'height': 195, 'weight': 207, 'Overall Rating': 89, 'Potential': '94', 'Value': '\\u20ac160M', 'Wage': '\\u20ac230K', 'Preferred Foot': 'Left', 'Weak Foot': 3, 'Skill Moves': 3, 'International Reputation': 4, 'Work Rate': 'High/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac308M', 'teams': {' Manchester City': '85', ' Norway': '76'}, 'attacking': {'Crossing': 85, 'Finishing': 76, 'Heading Accuracy': 47, 'Short Passing': 94}, 'skill': {'Dribbling': 74, 'Curve': 88, 'FK Accuracy': 78, 'Long Passing': 77}, 'power': {'Shot Power': 89, 'Jumping': 74, 'Stamina': 94, 'Strength': 74}, 'mentality': {'Aggression': 93, 'Interceptions': 87, 'Positioning': 87, 'Vision': 42, 'Penalties': 92}, 'defending': {'Defensive Awareness': 79, 'Standing Tackle': 86}, 'goalkeeping': {'GK Diving': 53, 'GK Handling': 29, 'GK Kicking': 7, 'GK Positioning': 14}, 'player_traits': ['Speed Dribbler (AI)', 'Power Header'], 'player_specialities': ['#Aerial Threat', '#Distance Shooter', '#Strength', '#Clinical Finisher', '#Complete Forward']}
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/200145?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/200389?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/190871?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/167495?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/230621?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/188545?units=mks>
# {'id': '188545', 'name': 'Robert Lewandowski', 'primary_position': 'ST', 'positions': ['ST', 'ST'], 'age': '33', 'birth_date': '1988/Aug/21', 'height': 185, 'weight': 179, 'Overall Rating': 91, 'Potential': '91', 'Value': '\\u20ac84M', 'Wage': '\\u20ac420K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 4, 'International Reputation': 5, 'Work Rate': 'High/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac172.2M', 'teams': {' FC Barcelona': '83', ' Poland': '78'}, 'attacking': {'Crossing': 83, 'Finishing': 78, 'Heading Accuracy': 71, 'Short Passing': 94}, 'skill': {'Dribbling': 84, 'Curve': 89, 'FK Accuracy': 85, 'Long Passing': 79}, 'power': {'Shot Power': 93, 'Jumping': 82, 'Stamina': 91, 'Strength': 85}, 'mentality': {'Aggression': 87, 'Interceptions': 84, 'Positioning': 81, 'Vision': 49, 'Penalties': 94}, 'defending': {'Defensive Awareness': 90, 'Standing Tackle': 88}, 'goalkeeping': {'GK Diving': 42, 'GK Handling': 19, 'GK Kicking': 15, 'GK Positioning': 6}, 'player_traits': ['Solid Player', 'Finesse Shot', 'Outside Foot Shot', 'Chip Shot (AI)'], 'player_specialities': ['#Aerial Threat', '#Distance Shooter', '#Clinical Finisher', '#Complete Forward']}
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/239818?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/218667?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.scraper] ERROR: Spider error processing <GET https://sofifa.com/player/212622?units=mks> (referer: None)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/content/fifa_crawler/fifa_crawler/spiders/collect_players_info.py", line 38, in parse
#     age = re.search(r'(\d{2})y\.o\.', meta_info[1]).group(1)
# AttributeError: 'NoneType' object has no attribute 'group'
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/202126?units=mks>
# {'id': '202126', 'name': 'Harry Kane', 'primary_position': 'ST', 'positions': ['ST', 'ST'], 'age': '28', 'birth_date': '1993/Jul/28', 'height': 188, 'weight': 196, 'Overall Rating': 89, 'Potential': '89', 'Value': '\\u20ac105.5M', 'Wage': '\\u20ac240K', 'Preferred Foot': 'Right', 'Weak Foot': 5, 'Skill Moves': 3, 'International Reputation': 4, 'Work Rate': 'High/ High', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac200.5M', 'teams': {' Tottenham Hotspur': '82', ' England': '84'}, 'attacking': {'Crossing': 82, 'Finishing': 84, 'Heading Accuracy': 80, 'Short Passing': 93}, 'skill': {'Dribbling': 84, 'Curve': 87, 'FK Accuracy': 83, 'Long Passing': 82}, 'power': {'Shot Power': 92, 'Jumping': 73, 'Stamina': 92, 'Strength': 79}, 'mentality': {'Aggression': 83, 'Interceptions': 86, 'Positioning': 80, 'Vision': 44, 'Penalties': 94}, 'defending': {'Defensive Awareness': 92, 'Standing Tackle': 92}, 'goalkeeping': {'GK Diving': 36, 'GK Handling': 38, 'GK Kicking': 8, 'GK Positioning': 10}, 'player_traits': ['Leadership', 'Long Passer (AI)', 'Long Shot Taker (AI)', 'Playmaker (AI)'], 'player_specialities': ['#Distance Shooter', '#Clinical Finisher']}
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/203376?units=mks>
# {'id': '203376', 'name': 'Virgil van Dijk', 'primary_position': 'CB', 'positions': ['LCB', 'CB'], 'age': '30', 'birth_date': '1991/Jul/08', 'height': 193, 'weight': 203, 'Overall Rating': 89, 'Potential': '89', 'Value': '\\u20ac84.5M', 'Wage': '\\u20ac220K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 2, 'International Reputation': 4, 'Work Rate': 'Medium/ High', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac156.3M', 'teams': {' Liverpool': '84', ' Netherlands': '82'}, 'attacking': {'Crossing': 84, 'Finishing': 82, 'Heading Accuracy': 53, 'Short Passing': 52}, 'skill': {'Dribbling': 79, 'Curve': 45, 'FK Accuracy': 70, 'Long Passing': 60}, 'power': {'Shot Power': 89, 'Jumping': 53, 'Stamina': 81, 'Strength': 88}, 'mentality': {'Aggression': 93, 'Interceptions': 64, 'Positioning': 85, 'Vision': 89, 'Penalties': 47}, 'defending': {'Defensive Awareness': 62, 'Standing Tackle': 90}, 'goalkeeping': {'GK Diving': 91, 'GK Handling': 86, 'GK Kicking': 13, 'GK Positioning': 10}, 'player_traits': ['Leadership', 'Long Passer (AI)', 'Power Header'], 'player_specialities': ['#Tackling\xa0', '#Tactician\xa0', '#Strength', '#Complete Defender']}
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/215914?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/200145?units=mks>
# {'id': '200145', 'name': 'Carlos Henrique Venancio Casimiro', 'primary_position': 'CDM', 'positions': ['CDM'], 'age': '30', 'birth_date': '1992/Feb/23', 'height': 185, 'weight': 185, 'Overall Rating': 89, 'Potential': '89', 'Value': '\\u20ac86M', 'Wage': '\\u20ac240K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 2, 'International Reputation': 3, 'Work Rate': 'Medium/ High', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac163.4M', 'teams': {' Manchester United': '82'}, 'attacking': {'Crossing': 82, 'Finishing': 62, 'Heading Accuracy': 64, 'Short Passing': 81}, 'skill': {'Dribbling': 65, 'Curve': 69, 'FK Accuracy': 72, 'Long Passing': 74}, 'power': {'Shot Power': 66, 'Jumping': 88, 'Stamina': 85, 'Strength': 88}, 'mentality': {'Aggression': 81, 'Interceptions': 91, 'Positioning': 89, 'Vision': 75, 'Penalties': 79}, 'defending': {'Defensive Awareness': 85, 'Standing Tackle': 90}, 'goalkeeping': {'GK Diving': 88, 'GK Handling': 13, 'GK Kicking': 14, 'GK Positioning': 16}, 'player_traits': ['Power Free-Kick', 'Solid Player', 'Dives Into Tackles (AI)', 'Long Passer (AI)'], 'player_specialities': ['#Tackling\xa0', '#Tactician\xa0', '#Strength', '#Complete Defender']}
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/200389?units=mks>
# {'id': '200389', 'name': 'Jan Oblak', 'primary_position': 'GK', 'positions': ['GK'], 'age': '29', 'birth_date': '1993/Jan/07', 'height': 188, 'weight': 192, 'Overall Rating': 89, 'Potential': '90', 'Value': '\\u20ac79M', 'Wage': '\\u20ac100K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 1, 'International Reputation': 5, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac167.9M', 'teams': {' Atlético Madrid': '83'}, 'attacking': {'Crossing': 83, 'Finishing': 13, 'Heading Accuracy': 11, 'Short Passing': 15}, 'skill': {'Dribbling': 13, 'Curve': 12, 'FK Accuracy': 13, 'Long Passing': 14}, 'power': {'Shot Power': 48, 'Jumping': 59, 'Stamina': 77, 'Strength': 42}, 'mentality': {'Aggression': 12, 'Interceptions': 36, 'Positioning': 24, 'Vision': 11, 'Penalties': 67}, 'defending': {'Defensive Awareness': 68, 'Standing Tackle': 27}, 'goalkeeping': {'GK Diving': 18, 'GK Handling': 86, 'GK Kicking': 90, 'GK Positioning': 79}, 'player_traits': ['GK Long Throw', 'Comes For Crosses'], 'player_specialities': []}
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/190871?units=mks>
# {'id': '190871', 'name': 'Neymar da Silva Santos J\\xfanior', 'primary_position': 'LW', 'positions': ['CAM'], 'age': '30', 'birth_date': '1992/Feb/05', 'height': 175, 'weight': 150, 'Overall Rating': 89, 'Potential': '89', 'Value': '\\u20ac99.5M', 'Wage': '\\u20ac200K', 'Preferred Foot': 'Right', 'Weak Foot': 5, 'Skill Moves': 5, 'International Reputation': 5, 'Work Rate': 'High/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac184.1M', 'teams': {' Paris Saint Germain': '84'}, 'attacking': {'Crossing': 84, 'Finishing': 83, 'Heading Accuracy': 83, 'Short Passing': 63}, 'skill': {'Dribbling': 86, 'Curve': 95, 'FK Accuracy': 88, 'Long Passing': 87}, 'power': {'Shot Power': 82, 'Jumping': 79, 'Stamina': 62, 'Strength': 79}, 'mentality': {'Aggression': 81, 'Interceptions': 63, 'Positioning': 37, 'Vision': 86, 'Penalties': 90}, 'defending': {'Defensive Awareness': 93, 'Standing Tackle': 35}, 'goalkeeping': {'GK Diving': 29, 'GK Handling': 9, 'GK Kicking': 9, 'GK Positioning': 15}, 'player_traits': ['Injury Prone', 'Flair', 'Speed Dribbler (AI)', 'Playmaker (AI)'], 'player_specialities': ['#Dribbler', '#FK Specialist', '#Acrobat']}
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/167495?units=mks>
# {'id': '167495', 'name': 'Manuel Peter Neuer', 'primary_position': 'GK', 'positions': ['RES', 'GK'], 'age': '36', 'birth_date': '1986/Mar/27', 'height': 193, 'weight': 205, 'Overall Rating': 89, 'Potential': '89', 'Value': '\\u20ac11.5M', 'Wage': '\\u20ac69K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 1, 'International Reputation': 5, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac19M', 'teams': {' FC Bayern München': '85', ' Germany': '85'}, 'attacking': {'Crossing': 85, 'Finishing': 85, 'Heading Accuracy': 15, 'Short Passing': 13}, 'skill': {'Dribbling': 60, 'Curve': 11, 'FK Accuracy': 30, 'Long Passing': 14}, 'power': {'Shot Power': 85, 'Jumping': 35, 'Stamina': 68, 'Strength': 77}, 'mentality': {'Aggression': 80, 'Interceptions': 16, 'Positioning': 29, 'Vision': 30, 'Penalties': 12}, 'defending': {'Defensive Awareness': 47, 'Standing Tackle': 70}, 'goalkeeping': {'GK Diving': 10, 'GK Handling': 11, 'GK Kicking': 87, 'GK Positioning': 88}, 'player_traits': ['Leadership', 'GK Long Throw', 'Rushes Out Of Goal', 'Comes For Crosses'], 'player_specialities': []}
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/230621?units=mks>
# {'id': '230621', 'name': 'Gianluigi Donnarumma', 'primary_position': 'GK', 'positions': ['GK', 'GK'], 'age': '23', 'birth_date': '1999/Feb/25', 'height': 196, 'weight': 198, 'Overall Rating': 88, 'Potential': '92', 'Value': '\\u20ac103.5M', 'Wage': '\\u20ac110K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 1, 'International Reputation': 3, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac199.2M', 'teams': {' Paris Saint Germain': '84', ' Italy': '83'}, 'attacking': {'Crossing': 84, 'Finishing': 83, 'Heading Accuracy': 12, 'Short Passing': 12}, 'skill': {'Dribbling': 36, 'Curve': 8, 'FK Accuracy': 28, 'Long Passing': 12}, 'power': {'Shot Power': 85, 'Jumping': 38, 'Stamina': 59, 'Strength': 72}, 'mentality': {'Aggression': 72, 'Interceptions': 18, 'Positioning': 30, 'Vision': 26, 'Penalties': 14}, 'defending': {'Defensive Awareness': 24, 'Standing Tackle': 65}, 'goalkeeping': {'GK Diving': 14, 'GK Handling': 16, 'GK Kicking': 90, 'GK Positioning': 82}, 'player_traits': ['Rushes Out Of Goal', 'Comes For Crosses'], 'player_specialities': []}
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/210257?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/208722?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/177003?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/192448?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/182521?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/200104?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/239818?units=mks>
# {'id': '239818', 'name': 'R\\xfaben dos Santos Gato Alves Dias', 'primary_position': 'CB', 'positions': ['LCB', 'LCB'], 'age': '25', 'birth_date': '1997/May/14', 'height': 187, 'weight': 181, 'Overall Rating': 88, 'Potential': '91', 'Value': '\\u20ac107.5M', 'Wage': '\\u20ac230K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 2, 'International Reputation': 3, 'Work Rate': 'Medium/ High', 'Body Type': 'Normal (185+)', 'Real Face': 'Yes', 'Release Clause': '\\u20ac206.9M', 'teams': {' Manchester City': '85', ' Portugal': '83'}, 'attacking': {'Crossing': 85, 'Finishing': 83, 'Heading Accuracy': 54, 'Short Passing': 29}, 'skill': {'Dribbling': 82, 'Curve': 32, 'FK Accuracy': 64, 'Long Passing': 46}, 'power': {'Shot Power': 89, 'Jumping': 56, 'Stamina': 74, 'Strength': 78}, 'mentality': {'Aggression': 90, 'Interceptions': 26, 'Positioning': 92, 'Vision': 86, 'Penalties': 39}, 'defending': {'Defensive Awareness': 45, 'Standing Tackle': 81}, 'goalkeeping': {'GK Diving': 88, 'GK Handling': 85, 'GK Kicking': 7, 'GK Positioning': 8}, 'player_traits': ['Leadership', 'Power Header'], 'player_specialities': ['#Tackling\xa0', '#Tactician\xa0', '#Strength', '#Complete Defender']}
# 2023-03-19 16:15:16 [scrapy.core.scraper] ERROR: Spider error processing <GET https://sofifa.com/player/218667?units=mks> (referer: None)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/content/fifa_crawler/fifa_crawler/spiders/collect_players_info.py", line 38, in parse
#     age = re.search(r'(\d{2})y\.o\.', meta_info[1]).group(1)
# AttributeError: 'NoneType' object has no attribute 'group'
# 2023-03-19 16:15:16 [scrapy.core.scraper] ERROR: Spider error processing <GET https://sofifa.com/player/215914?units=mks> (referer: None)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/content/fifa_crawler/fifa_crawler/spiders/collect_players_info.py", line 38, in parse
#     age = re.search(r'(\d{2})y\.o\.', meta_info[1]).group(1)
# AttributeError: 'NoneType' object has no attribute 'group'
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/207865?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/231866?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/210257?units=mks>
# {'id': '210257', 'name': 'Ederson Santana de Moraes', 'primary_position': 'GK', 'positions': ['GK'], 'age': '28', 'birth_date': '1993/Aug/17', 'height': 188, 'weight': 190, 'Overall Rating': 88, 'Potential': '90', 'Value': '\\u20ac78M', 'Wage': '\\u20ac210K', 'Preferred Foot': 'Left', 'Weak Foot': 3, 'Skill Moves': 1, 'International Reputation': 3, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac150.2M', 'teams': {' Manchester City': '85'}, 'attacking': {'Crossing': 85, 'Finishing': 20, 'Heading Accuracy': 14, 'Short Passing': 14}, 'skill': {'Dribbling': 18, 'Curve': 23, 'FK Accuracy': 15, 'Long Passing': 20}, 'power': {'Shot Power': 48, 'Jumping': 68, 'Stamina': 66, 'Strength': 41}, 'mentality': {'Aggression': 18, 'Interceptions': 38, 'Positioning': 27, 'Vision': 20, 'Penalties': 70}, 'defending': {'Defensive Awareness': 70, 'Standing Tackle': 29}, 'goalkeeping': {'GK Diving': 8, 'GK Handling': 86, 'GK Kicking': 82, 'GK Positioning': 91}, 'player_traits': ['Long Passer (AI)', 'Rushes Out Of Goal', 'Comes For Crosses'], 'player_specialities': []}
# 2023-03-19 16:15:16 [scrapy.core.scraper] ERROR: Spider error processing <GET https://sofifa.com/player/208722?units=mks> (referer: None)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/content/fifa_crawler/fifa_crawler/spiders/collect_players_info.py", line 38, in parse
#     age = re.search(r'(\d{2})y\.o\.', meta_info[1]).group(1)
# AttributeError: 'NoneType' object has no attribute 'group'
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/177003?units=mks>
# {'id': '177003', 'name': 'Luka Modri\\u0107', 'primary_position': 'CM', 'positions': ['RCM', 'RCM'], 'age': '36', 'birth_date': '1985/Sep/09', 'height': 172, 'weight': 146, 'Overall Rating': 88, 'Potential': '88', 'Value': '\\u20ac29M', 'Wage': '\\u20ac230K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 4, 'International Reputation': 4, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Lean (170-185)', 'Real Face': 'Yes', 'Release Clause': '\\u20ac59.5M', 'teams': {' Real Madrid': '85', ' Croatia': '80'}, 'attacking': {'Crossing': 85, 'Finishing': 80, 'Heading Accuracy': 86, 'Short Passing': 72}, 'skill': {'Dribbling': 91, 'Curve': 76, 'FK Accuracy': 85, 'Long Passing': 85}, 'power': {'Shot Power': 88, 'Jumping': 92, 'Stamina': 79, 'Strength': 67}, 'mentality': {'Aggression': 58, 'Interceptions': 82, 'Positioning': 62, 'Vision': 80, 'Penalties': 78}, 'defending': {'Defensive Awareness': 83, 'Standing Tackle': 92}, 'goalkeeping': {'GK Diving': 75, 'GK Handling': 72, 'GK Kicking': 13, 'GK Positioning': 9}, 'player_traits': ['Long Passer (AI)', 'Long Shot Taker (AI)', 'Playmaker (AI)', 'Outside Foot Shot'], 'player_specialities': ['#Playmaker\xa0', '#Crosser', '#Acrobat', '#Complete Midfielder']}
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/228702?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/192448?units=mks>
# {'id': '192448', 'name': 'Marc-Andr\\xe9 ter Stegen', 'primary_position': 'GK', 'positions': ['GK', 'SUB'], 'age': '30', 'birth_date': '1992/Apr/30', 'height': 187, 'weight': 187, 'Overall Rating': 88, 'Potential': '89', 'Value': '\\u20ac68.5M', 'Wage': '\\u20ac210K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 1, 'International Reputation': 4, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac145.6M', 'teams': {' FC Barcelona': '83', ' Germany': '85'}, 'attacking': {'Crossing': 83, 'Finishing': 85, 'Heading Accuracy': 18, 'Short Passing': 14}, 'skill': {'Dribbling': 61, 'Curve': 14, 'FK Accuracy': 21, 'Long Passing': 18}, 'power': {'Shot Power': 85, 'Jumping': 43, 'Stamina': 65, 'Strength': 79}, 'mentality': {'Aggression': 78, 'Interceptions': 10, 'Positioning': 43, 'Vision': 22, 'Penalties': 11}, 'defending': {'Defensive Awareness': 25, 'Standing Tackle': 70}, 'goalkeeping': {'GK Diving': 13, 'GK Handling': 10, 'GK Kicking': 86, 'GK Positioning': 85}, 'player_traits': ['Rushes Out Of Goal', 'Comes For Crosses', 'Saves with Feet'], 'player_specialities': []}
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/199556?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/210514?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.scraper] ERROR: Spider error processing <GET https://sofifa.com/player/182521?units=mks> (referer: None)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/content/fifa_crawler/fifa_crawler/spiders/collect_players_info.py", line 38, in parse
#     age = re.search(r'(\d{2})y\.o\.', meta_info[1]).group(1)
# AttributeError: 'NoneType' object has no attribute 'group'
# 2023-03-19 16:15:16 [scrapy.core.scraper] ERROR: Spider error processing <GET https://sofifa.com/player/200104?units=mks> (referer: None)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/content/fifa_crawler/fifa_crawler/spiders/collect_players_info.py", line 38, in parse
#     age = re.search(r'(\d{2})y\.o\.', meta_info[1]).group(1)
# AttributeError: 'NoneType' object has no attribute 'group'
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/205452?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/207865?units=mks>
# {'id': '207865', 'name': 'Marcos Ao\\xe1s Corr\\xeaa', 'primary_position': 'CB', 'positions': ['RCB'], 'age': '28', 'birth_date': '1994/May/14', 'height': 183, 'weight': 165, 'Overall Rating': 88, 'Potential': '90', 'Value': '\\u20ac92M', 'Wage': '\\u20ac170K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 3, 'International Reputation': 3, 'Work Rate': 'Medium/ High', 'Body Type': 'Normal (170-185)', 'Real Face': 'Yes', 'Release Clause': '\\u20ac177.1M', 'teams': {' Paris Saint Germain': '84'}, 'attacking': {'Crossing': 84, 'Finishing': 68, 'Heading Accuracy': 59, 'Short Passing': 88}, 'skill': {'Dribbling': 35, 'Curve': 69, 'FK Accuracy': 58, 'Long Passing': 32}, 'power': {'Shot Power': 66, 'Jumping': 65, 'Stamina': 92, 'Strength': 82}, 'mentality': {'Aggression': 45, 'Interceptions': 81, 'Positioning': 89, 'Vision': 70, 'Penalties': 76}, 'defending': {'Defensive Awareness': 86, 'Standing Tackle': 90}, 'goalkeeping': {'GK Diving': 89, 'GK Handling': 6, 'GK Kicking': 6, 'GK Positioning': 12}, 'player_traits': ['Power Header', 'Team Player'], 'player_specialities': ['#Tackling\xa0', '#Tactician\xa0']}
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/193041?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/231866?units=mks>
# {'id': '231866', 'name': 'Rodrigo Hern\\xe1ndez Cascante', 'primary_position': 'CDM', 'positions': ['CDM', 'CDM'], 'age': '26', 'birth_date': '1996/Jun/22', 'height': 191, 'weight': 181, 'Overall Rating': 87, 'Potential': '89', 'Value': '\\u20ac88.5M', 'Wage': '\\u20ac200K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 3, 'International Reputation': 3, 'Work Rate': 'Medium/ High', 'Body Type': 'Normal (185+)', 'Real Face': 'Yes', 'Release Clause': '\\u20ac170.4M', 'teams': {' Manchester City': '85', ' Spain': '83'}, 'attacking': {'Crossing': 85, 'Finishing': 83, 'Heading Accuracy': 63, 'Short Passing': 64}, 'skill': {'Dribbling': 86, 'Curve': 59, 'FK Accuracy': 78, 'Long Passing': 65}, 'power': {'Shot Power': 82, 'Jumping': 65, 'Stamina': 89, 'Strength': 72}, 'mentality': {'Aggression': 84, 'Interceptions': 82, 'Positioning': 82, 'Vision': 83, 'Penalties': 75}, 'defending': {'Defensive Awareness': 46, 'Standing Tackle': 85}, 'goalkeeping': {'GK Diving': 86, 'GK Handling': 78, 'GK Kicking': 10, 'GK Positioning': 10}, 'player_traits': ['Solid Player', 'Long Shot Taker (AI)'], 'player_specialities': []}
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/20801?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/215698?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/193080?units=mks> (referer: None)
# 2023-03-19 16:15:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/228702?units=mks>
# ...
# {'id': '231281', 'name': 'Trent Alexander-Arnold', 'primary_position': 'CM', 'positions': ['RB', 'SUB'], 'age': '23', 'birth_date': '1998/Oct/07', 'height': 180, 'weight': 152, 'Overall Rating': 85, 'Potential': '88', 'Value': '\\u20ac68M', 'Wage': '\\u20ac130K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 3, 'International Reputation': 3, 'Work Rate': 'High/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '\\u20ac130.9M', 'teams': {' Liverpool': '84', ' England': '84'}, 'attacking': {'Crossing': 84, 'Finishing': 84, 'Heading Accuracy': 91, 'Short Passing': 62}, 'skill': {'Dribbling': 87, 'Curve': 63, 'FK Accuracy': 78, 'Long Passing': 87}, 'power': {'Shot Power': 82, 'Jumping': 73, 'Stamina': 82, 'Strength': 66}, 'mentality': {'Aggression': 66, 'Interceptions': 75, 'Positioning': 69, 'Vision': 82, 'Penalties': 78}, 'defending': {'Defensive Awareness': 55, 'Standing Tackle': 80}, 'goalkeeping': {'GK Diving': 81, 'GK Handling': 78, 'GK Kicking': 14, 'GK Positioning': 15}, 'player_traits': ['Early Crosser', 'Long Passer (AI)', 'Long Shot Taker (AI)'], 'player_specialities': ['#Crosser']}
# 2023-03-19 16:15:17 [scrapy.core.scraper] ERROR: Spider error processing <GET https://sofifa.com/player/224458?units=mks> (referer: None)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/content/fifa_crawler/fifa_crawler/spiders/collect_players_info.py", line 38, in parse
#     age = re.search(r'(\d{2})y\.o\.', meta_info[1]).group(1)
# AttributeError: 'NoneType' object has no attribute 'group'
# 2023-03-19 16:15:17 [scrapy.core.scraper] ERROR: Spider error processing <GET https://sofifa.com/player/222665?units=mks> (referer: None)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/content/fifa_crawler/fifa_crawler/spiders/collect_players_info.py", line 38, in parse
#     age = re.search(r'(\d{2})y\.o\.', meta_info[1]).group(1)
# AttributeError: 'NoneType' object has no attribute 'group'
# 2023-03-19 16:15:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/212190?units=mks> (referer: None)
# 2023-03-19 16:15:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/213345?units=mks> (referer: None)
# 2023-03-19 16:15:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/216594?units=mks> (referer: None)
# 2023-03-19 16:15:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/209981?units=mks> (referer: None)
# 2023-03-19 16:15:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/209989?units=mks> (referer: None)
# 2023-03-19 16:15:17 [scrapy.core.scraper] ERROR: Spider error processing <GET https://sofifa.com/player/212190?units=mks> (referer: None)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/content/fifa_crawler/fifa_crawler/spiders/collect_players_info.py", line 38, in parse
#     age = re.search(r'(\d{2})y\.o\.', meta_info[1]).group(1)
# AttributeError: 'NoneType' object has no attribute 'group'
# 2023-03-19 16:15:17 [scrapy.core.scraper] ERROR: Spider error processing <GET https://sofifa.com/player/213345?units=mks> (referer: None)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/content/fifa_crawler/fifa_crawler/spiders/collect_players_info.py", line 38, in parse
#     age = re.search(r'(\d{2})y\.o\.', meta_info[1]).group(1)
# AttributeError: 'NoneType' object has no attribute 'group'
# 2023-03-19 16:15:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/216594?units=mks>
# {'id': '216594', 'name': 'Nabil Fekir', 'primary_position': 'CAM', 'positions': ['SUB'], 'age': '28', 'birth_date': '1993/Jul/18', 'height': 173, 'weight': 165, 'Overall Rating': 85, 'Potential': '85', 'Value': '\\u20ac54.5M', 'Wage': '\\u20ac48K', 'Preferred Foot': 'Left', 'Weak Foot': 4, 'Skill Moves': 4, 'International Reputation': 3, 'Work Rate': 'High/ Medium', 'Body Type': 'Stocky (170-185)', 'Real Face': 'Yes', 'Release Clause': '\\u20ac114.5M', 'teams': {' Real Betis': '79'}, 'attacking': {'Crossing': 79, 'Finishing': 81, 'Heading Accuracy': 82, 'Short Passing': 50}, 'skill': {'Dribbling': 77, 'Curve': 89, 'FK Accuracy': 83, 'Long Passing': 79}, 'power': {'Shot Power': 91, 'Jumping': 84, 'Stamina': 64, 'Strength': 79}, 'mentality': {'Aggression': 83, 'Interceptions': 82, 'Positioning': 36, 'Vision': 82, 'Penalties': 87}, 'defending': {'Defensive Awareness': 90, 'Standing Tackle': 36}, 'goalkeeping': {'GK Diving': 30, 'GK Handling': 15, 'GK Kicking': 9, 'GK Positioning': 8}, 'player_traits': ['Power Free-Kick', 'Finesse Shot', 'Flair', 'Outside Foot Shot'], 'player_specialities': ['#Dribbler']}
# 2023-03-19 16:15:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/209981?units=mks>
# {'id': '209981', 'name': 'Yassine Bounou', 'primary_position': 'GK', 'positions': ['GK', 'GK'], 'age': '31', 'birth_date': '1991/Apr/05', 'height': 195, 'weight': 172, 'Overall Rating': 85, 'Potential': '85', 'Value': '\\u20ac28.5M', 'Wage': '\\u20ac38K', 'Preferred Foot': 'Left', 'Weak Foot': 2, 'Skill Moves': 1, 'International Reputation': 1, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Lean (185+)', 'Real Face': 'Yes', 'Release Clause': '\\u20ac59.9M', 'teams': {' Sevilla': '80', ' Morocco': '77'}, 'attacking': {'Crossing': 80, 'Finishing': 77, 'Heading Accuracy': 15, 'Short Passing': 14}, 'skill': {'Dribbling': 39, 'Curve': 13, 'FK Accuracy': 20, 'Long Passing': 12}, 'power': {'Shot Power': 83, 'Jumping': 29, 'Stamina': 59, 'Strength': 48}, 'mentality': {'Aggression': 69, 'Interceptions': 19, 'Positioning': 25, 'Vision': 12, 'Penalties': 10}, 'defending': {'Defensive Awareness': 24, 'Standing Tackle': 57}, 'goalkeeping': {'GK Diving': 18, 'GK Handling': 15, 'GK Kicking': 83, 'GK Positioning': 84}, 'player_traits': ['GK Long Throw', 'Comes For Crosses', 'Saves with Feet'], 'player_specialities': []}
# 2023-03-19 16:15:17 [scrapy.core.scraper] ERROR: Spider error processing <GET https://sofifa.com/player/209989?units=mks> (referer: None)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/usr/local/lib/python3.9/dist-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/content/fifa_crawler/fifa_crawler/spiders/collect_players_info.py", line 38, in parse
#     age = re.search(r'(\d{2})y\.o\.', meta_info[1]).group(1)
# AttributeError: 'NoneType' object has no attribute 'group'
# 2023-03-19 16:15:17 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-03-19 16:15:17 [scrapy.extensions.feedexport] INFO: Stored json feed (45 items) in: dataset/players_info.json
# 2023-03-19 16:15:17 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 24379,
#  'downloader/request_count': 73,
#  'downloader/request_method_count/GET': 73,
#  'downloader/response_bytes': 1009117,
#  'downloader/response_count': 73,
#  'downloader/response_status_count/200': 72,
#  'downloader/response_status_count/403': 1,
#  'dupefilter/filtered': 708,
#  'elapsed_time_seconds': 2.187954,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 3, 19, 16, 15, 17, 872857),
#  'httpcompression/response_bytes': 5010382,
#  'httpcompression/response_count': 73,
#  'item_scraped_count': 45,
#  'log_count/DEBUG': 133,
#  'log_count/ERROR': 27,
#  'log_count/INFO': 11,
#  'memusage/max': 156860416,
#  'memusage/startup': 156860416,
#  'response_received_count': 73,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/403': 1,
#  'scheduler/dequeued': 72,
#  'scheduler/dequeued/memory': 72,
#  'scheduler/enqueued': 72,
#  'scheduler/enqueued/memory': 72,
#  'spider_exceptions/AttributeError': 27,
#  'start_time': datetime.datetime(2023, 3, 19, 16, 15, 15, 684903)}
# 2023-03-19 16:15:17 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# Sau khi đã có thông tin chi tiết của 720 cầu thủ, các bạn sẽ tiến hành đọc file <b>players_info.json</b> vào pandas với tên gọi <b>df_players_info</b> và kiểm tra lại với file của mình xem dữ liệu các bạn thu thập là khớp chưa. Nếu đã trùng khớp hai file thì bạn sẽ đến với bước tiền xử lý dữ liệu.

# %%
# YOUR CODE HERE
raise NotImplementedError()

assert_frame_equal(df_players_info, df_test)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-13-c65c6ffa1c81> in <module>
#       1 # YOUR CODE HERE
# ----> 2 raise NotImplementedError()
#       3
#       4 assert_frame_equal(df_players_info, df_test)
#
# NotImplementedError:

# %% [markdown]
# <h2><b>Tiền xử lý dữ liệu</b></h2>
#
# <b>1)</b> Sau khi đã kiểm tra và khớp với dữ liệu từ file mình đã cung cấp, nhiệm vụ đầu tiên của các bạn trong bước tiền xử lý dữ liệu là cần phân tách các chỉ số cụ thể của mỗi cầu thủ. Như chúng ta thấy, ở mỗi cột <b>attacking, skill, movement</b> sẽ là một từ điển chứa chi tiết cụ thể từng chỉ số chi tiết ở trong đó. Do đó, chúng ta sẽ cần phân tách các từ điển này thành các cột cụ thể và nhiệm vụ khi này của bạn là hoàn thành hàm <b>split_players_info()</b> ở bên dưới rồi lưu lại vào một dataframe mới với tên <b>df_split_players_info</b>.

# %%
def split_players_info():
    # YOUR CODE HERE
    raise NotImplementedError()
    
    return df_split_players_info

# %%
# TEST
df_split_players_info = split_players_info()
df_split_players_info_test = pd.read_json('/content/split_players_info.json', encoding='utf-8-sig')
assert_frame_equal(df_split_players_info.iloc[:, 23:], df_split_players_info_test.iloc[:, 23:])

# %% [markdown]
# <b>2)</b> Vì cột giá trị của cầu thủ (Value) và tiền lương (Wage) đang ở dạng viết tắt nên các bạn cần chuyển hai cột này về dạng số (float) bằng cách hoàn thành hàm <b>value_and_wage_to_float(col)</b>. Ví dụ, cầu thủ A có giá trị là €1M và tiền lương là €1K, hai cột này sau khi được tiền xử lý thì cầu thủ A sẽ có giá trị là 1000000.0 và tiền lương là 1000. Ngoài ra, bạn cần lưu ý kiểm tra các cột này có giá trị bị thiếu hay không, nếu có sẽ điền là 0.0 và ngược lại sẽ tiền xử lý như trên.

# %%
def value_and_wage_to_float(col):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# TEST
assert df_split_players_info['Wage'].to_list()[:5] == [230000.0, 350000.0, 420000.0, 450000.0, 195000.0]
assert df_split_players_info['Wage'].to_list()[-5:] == [41000.0, 21000.0, 59000.0, 15000.0, 50000.0]
assert df_split_players_info['Value'].to_list()[:5] == [190500000.0, 107500000.0, 84000000.0, 64000000.0, 54000000.0]
assert df_split_players_info['Value'].to_list()[-5:] == [32000000.0, 9500000.0, 19500000.0, 22000000.0, 20000000.0]

# %% [markdown]
# <b>3)</b> Vì cột giá trị giải phóng hợp đồng (Release Clause) của cầu thủ đang ở dạng object, các bạn cần chuyển về dạng chuỗi và sau đó tiến hành tiền xử lý tương tự như hai cột <b>Value</b> và <b>Wage</b> ở trên bằng cách hoàn thành hàm <b>release_clause_to_float(col)</b>.

# %%
import numpy as np

def release_clause_to_float(col):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# TEST
assert df_split_players_info['Release Clause'].to_list()[:5] == [366700000.0, 198900000.0, 172200000.0, 131199999.99999999, 99900000.0]
assert df_split_players_info['Release Clause'].to_list()[-5:] == [0.0, 17100000.0, 38500000.0, 48400000.0, 35500000.0]
